# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#     .header {
#         padding-bottom: 10px;
#         margin-bottom: 10px;
#         font-size: 50px;
#         font-weight: bold;
#         color: white;
#         text-align: left;
#         font-family: Poppins;
#     }
#
#     .subheader {
#         font-size: 22px;
#         color: gray;
#         text-align: left;
#     }
#
#     .divider {
#         height: 2px;
#         border-width: 0;
#         color: gray;
#         background-color: gray;
#         box-shadow: 0px 2.5px 5px rgba(0, 0, 0, 0.2);
#     }
# </style>
# </head>
# <body>
#     <p class="header"><b>Assessing Wine Excellence: Exploring, Predicting, and Deployment </b></p>
#     <p class="subheader">Unveiling Wine Quality Through Data Science: Exploring and Constructing a Predictive Model, from Grapes to Glasses.</p>
#     <hr class="divider">
# </body>
# </html>

# %% [markdown]
# <h3 style="border-bottom: 1px solid #ccc;
#             padding-bottom: 10px;
#             margin-bottom: 10px;
#             font-size: 16px;
#             font-weight: bold;
#             color: White;">Table of Contents</h3>
#
# <ul style="list-style-type: disc; padding: 0; padding-left: 20px;">
#     <li><a href="#introduction" style="color: white; text-decoration: none;">Introduction</a></li>
#     <li><a href="#exploratory_data_analysis" style="color: white; text-decoration: none;">Exploratory Data Analysis</a></li>
#     <li><a href="#feature_value_distribution" style="color: white; text-decoration: none;">Feature Value Distribution</a></li>
#     <li><a href="#feature_engineering" style="color: white; text-decoration: none;">Feature Engineering</a></li>
#     <li><a href="#standardizing" style="color: white; text-decoration: none;">Standardizing</a></li>
#     <li><a href="#modelling" style="color: white; text-decoration: none;">Modelling</a></li>
#     <li><a href="#neural_network" style="color: white; text-decoration: none;">Neural Network</a></li>
#     <li><a href="#conclusion" style="color: white; text-decoration: none;">Conclusion</a></li>
# </ul>

# %% [markdown]
# <h1 id="introduction" style="border-bottom: 1px solid #ccc;
#                      padding-bottom: 10px;
#                      margin-bottom: 10px;
#                      font-size: 38px;
#                      font-weight: bold;
#                      color: white; /* Changed from black to white */
#                      font-family: Poppins">Introduction</h1>

# %% [markdown]
# Although I'm not well-versed in wine tasting, I am genuinely intrigued by the process of wine scoring. Over time, I've come to realize that certain wines are more enjoyable to me than others. Interestingly, my perception of a good wine seems to have little correlation with its price, brand, or country of origin. Even with some wines that bear impressive price tags, I've found them less than palatable. This sentiment holds true for wines from prestigious brands and those originating from regions like France or Argentina.
#
# In an effort to avoid the disappointment of unfinished wine bottles at dinners or gatherings, I've adopted a strategy of purchasing wines based on their scores. I'm aware that these scores are highly subjective in nature. A wine rating is essentially a judgment assigned by wine critics after evaluating a wine, encapsulating their overall impression of the wine. It's a personal assessment, often conveyed through a numerical rating.
#
# Despite the subjectivity involved, I must admit that my experience with this approach, which relies on selecting wines with high scores, has been quite positive. Nonetheless, I've recognized a limitation in this method: it restricts my options to wines that have been scored. This limitation has led me to yearn for the ability to access exceptional wines from vineyards that lack exposure to these prestigious yet costly wine critics.
#
# This brings me to an intriguing question: Is there a systematic way to score wines? Could there potentially be an automated method for wine scoring?
#
#
# **Dataset and Features**
#
# The dataset employed in this research was sourced from the UCI Machine Learning Repository [link](https://archive.ics.uci.edu/dataset/186/wine+quality). The dataset encompasses wines originating from Minho, Portugal, specifically focusing on two distinct variants: red and white "Vinho Verde" wines. The dataset comprises two subsets, each pertaining to one of the variants. Within these subsets, there are eleven variables encompassing both physicochemical attributes (outlined in the table below) and a sensory quality score, which is rated on a scale from 0 to 10. Notably, the dataset does not encompass information about grape types, wine brands, or wine selling prices.
#
# In the scope of this investigation, I merged the two datasets to facilitate the exploration of binary classification. The objective was to ascertain the optimal set of attributes that would yield the most effective outcomes in predicting whether a given sample corresponds to red or white wine.

# %% [markdown]
# <table style="font-family: Arial, sans-serif; font-size: 13px;">
#   <tr>
#     <th><b>Attribute</b></th>
#     <th><b>Description</b></th>
#   </tr>
#   <tr>
#     <td><b>Fixed Acidity</b></td>
#     <td>This attribute represents the presence of fixed acids in the wine, such as tartaric and malic acid, contributing to taste and preservation.</td>
#   </tr>
#   <tr>
#     <td><b>Volatile Acidity</b></td>
#     <td>This attribute quantifies the volatile acids, including acetic acid, which can impart undesirable taste and odor to the wine.</td>
#   </tr>
#   <tr>
#     <td><b>Citric Acid</b></td>
#     <td>Citric acid, found in citrus fruits, adds a tangy flavor to the wine.</td>
#   </tr>
#   <tr>
#     <td><b>Residual Sugar</b></td>
#     <td>This attribute measures unfermented sugar content, influencing the wine's sweetness and taste.</td>
#   </tr>
#   <tr>
#     <td><b>Chlorides</b></td>
#     <td>Chlorides signify salt content in the wine, impacting its flavor profile.</td>
#   </tr>
#   <tr>
#     <td><b>Free Sulfur Dioxide</b></td>
#     <td>This attribute denotes sulfur dioxide that remains unreacted in the wine.</td>
#   </tr>
#   <tr>
#     <td><b>Total Sulfur Dioxide</b></td>
#     <td>Total sulfur dioxide includes both free and bound forms of sulfur dioxide.</td>
#   </tr>
#   <tr>
#     <td><b>Density</b></td>
#     <td>Density reflects the connection between alcohol content and grape variety in the wine.</td>
#   </tr>
#   <tr>
#     <td><b>pH</b></td>
#     <td>pH serves as a measure of the wine's acidity or basicity.</td>
#   </tr>
#   <tr>
#     <td><b>Sulfates</b></td>
#     <td>Sulfates, a type of preservative, influence both preservation and flavor of the wine.</td>
#   </tr>
#   <tr>
#     <td><b>Alcohol</b></td>
#     <td>Alcohol percentage impacts the wine's body and flavor characteristics.</td>
#   </tr>
#   <tr>
#     <td><b>Quality</b></td>
#     <td>Target variable, assessed on a scale of 0 to 10.</td>
#   </tr>
# </table>

# %% [markdown]
# <h1 id = 'exploratory_data_analysis' style="border-bottom: 1px solid #ccc;
#                         padding-bottom: 10px;
#                         margin-bottom: 10px;
#                         font-size: 38px;
#                         font-weight: bold;
#                         color: white;
#                         font-family: Poppins">Exploratory Data Analysis</h1>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
import warnings
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout
warnings.filterwarnings("ignore")
# Out:
# 2023-08-18 22:50:30.672090: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-18 22:50:30.695622: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-18 22:50:30.696230: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-18 22:50:31.126171: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
redwine_dir = r'./data/winequality-red.csv'
whitewine_dir = r'./data/winequality-white.csv'
df_redwine = pd.read_csv(redwine_dir, sep=';')
df_whitewine= pd.read_csv(whitewine_dir, sep=';')

# %% [markdown]
# ## Multiclassfication Dataset Exploratory Data Analysis

# %%
def plot_correlation(df):
    '''
    This function is responsible for plotting a correlation map among features in the dataset.
    '''
    corr = np.round(df.corr(), 2)
    mask = np.triu(np.ones_like(corr, dtype=bool))
    c_mask = np.where(~mask, corr, np.nan)

    fig, ax = plt.subplots(figsize=(10, 8))
    heatmap = ax.imshow(c_mask, cmap='Blues', aspect='auto', vmin=-1, vmax=1)

    ax.set_xticks(np.arange(len(corr.columns)))
    ax.set_yticks(np.arange(len(corr.columns)))
    ax.set_xticklabels(corr.columns, rotation=45, ha="right")
    ax.set_yticklabels(corr.columns)

    for i in range(len(corr.columns)):
        for j in range(len(corr.columns)):
            if not np.isnan(c_mask[i, j]):
                text = ax.text(j, i, c_mask[i, j], ha="center", va="center", color="black")

    plt.colorbar(heatmap, label='Correlation')
    plt.title('Feature Correlation Heatmap')
    plt.xlabel('Features')
    plt.ylabel('Features')
    plt.tight_layout()

    plt.show()

# %%
plot_correlation(df_redwine)

# %% [markdown]
# We used correlation heatmaps to visualize relationships between features.

# %%
def visualize_labels(df, x, y, label_column):
    """
    Visualize binary labels on a 2D scatter plot.

    Args:
    df (pd.DataFrame): The input dataframe.
    x (str): The column name for the x-axis.
    y (str): The column name for the y-axis.
    label_column (str): The column name for the binary labels.

    Returns:
    None
    """
    plt.figure(figsize=(10, 6))
    plt.scatter(df[x], df[y], c=df[label_column], cmap='coolwarm', marker='o')
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(f'2D Scatter Plot with Binary Labels ({x} vs {y})')
    plt.colorbar(label=label_column)
    plt.show()

# %%
visualize_labels(df_redwine, 'fixed acidity', 'citric acid', 'quality')

# %%
visualize_labels(df_whitewine, 'fixed acidity', 'citric acid', 'quality')

# %% [markdown]
# ## Binary Classification Dataset Exploratory Data Analysis
#
# We are going to merge the two datasets, drop `quality` feature and create label feature that we will use for the binary classification.

# %%
df_redwine_b =  df_redwine.copy()
df_whitewine_b = df_whitewine.copy()

df_redwine_b.drop('quality', axis = 1, inplace = True)
df_whitewine_b.drop('quality', axis = 1, inplace = True)

# O = redwine; 1= whitewine
df_redwine_b['wine_type'] = 0
df_whitewine_b['wine_type']= 1

# %%
df_whitewine_b.columns == df_redwine_b.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
len(df_whitewine_b.columns == df_redwine_b.columns)
# Out:
# 12

# %%
merge_df = pd.concat([df_redwine_b,
                      df_whitewine_b],
                      axis = 0)
merge_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  wine_type
# 0      9.4          0
# 1      9.8          0
# ...

# %%
merge_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
merge_df.shape
# Out:
# (6497, 12)

# %%
merge_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'wine_type'],
#       dtype='object')

# %%
label_count = merge_df['wine_type'].value_counts()
fig,axes = plt.subplots(nrows=1, ncols=2, figsize=(20,6))

sns.set_theme(style='darkgrid', palette='pastel')
color = sns.color_palette(palette='pastel')
explode = [0.02]*len(label_count)

axes[0].pie(label_count.values, labels=label_count.index, autopct='%1.1f%%', colors=color, explode=explode)
axes[0].set_title('Percentage Label',fontsize=16)

sns.barplot(x=label_count.index, y=label_count.values, ax=axes[1])
axes[1].set_title('Count Label',fontsize=16)
axes[1].set_xlabel('Label')
axes[1].set_ylabel('Count')

fig.suptitle('Visual Label Count',fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
#  The distribution of wine types using both a pie chart (showing the proportions of each type) and a bar plot (showing the actual counts of each type).

# %% [markdown]
# <h1 id = 'feature_engineering' style="border-bottom: 1px solid #ccc;
#                         padding-bottom: 10px;
#                         margin-bottom: 10px;
#                         font-size: 38px;
#                         font-weight: bold;
#                         color: White;
#                         font-family: Poppins">Feature Engineering</h1>

# %% [markdown]
# Here are the descriptions of the new columns:
#
# <table style="font-family: Arial, sans-serif; font-size: 13px;">
#   <tr>
#     <th><b>Attribute</b></th>
#     <th><b>Description</b></th>
#   </tr>
#   <tr>
#     <td><b>total_acidity</b></td>
#     <td>The sum of fixed acidity, volatile acidity, and citric acid. Represents the overall acidity content in the wine.</td>
#   </tr>
#   <tr>
#     <td><b>acidity_to_pH_ratio</b></td>
#     <td>The ratio of total acidity to pH. Reflects the acidity level relative to pH, influencing perceived sourness.</td>
#   </tr>
#   <tr>
#     <td><b>free_sulfur_dioxide_to_total_sulfur_dioxide_ratio</b></td>
#     <td>The ratio of free sulfur dioxide to total sulfur dioxide. Indicates the proportion of free sulfur dioxide for preservation and stability.</td>
#   </tr>
#   <tr>
#     <td><b>alcohol_to_acidity_ratio</b></td>
#     <td>The ratio of alcohol content to total acidity. Offers insight into alcohol-acidity balance affecting taste and feel.</td>
#   </tr>
#   <tr>
#     <td><b>residual_sugar_to_citric_acid_ratio</b></td>
#     <td>The ratio of residual sugar to citric acid. Shows sweetness-tartness interplay in the wine.</td>
#   </tr>
#   <tr>
#     <td><b>alcohol_to_density_ratio</b></td>
#     <td>The ratio of alcohol content to density. Indicates alcohol concentration relative to wine density.</td>
#   </tr>
#   <tr>
#     <td><b>total_alkalinity</b></td>
#     <td>The sum of pH and alcohol content. Reflects total alkalinity influenced by pH and alcohol.</td>
#   </tr>
#   <tr>
#     <td><b>total_minerals</b></td>
#     <td>The sum of chlorides, sulphates, and residual sugar. Reflects combined mineral presence impacting taste and mouthfeel.</td>
#   </tr>
# </table>

# %% [markdown]
# MultiClassification Feature Engineeing

# %%
df_whitewine_m = df_whitewine.copy()
# Creating new columns
df_whitewine_m.columns = df_whitewine_m.columns.str.replace(' ', '_')
df_whitewine_m['total_acidity'] = df_whitewine_m['fixed_acidity'] + df_whitewine_m['volatile_acidity'] + df_whitewine_m['citric_acid']
df_whitewine_m['acidity_to_pH_ratio'] = df_whitewine_m['total_acidity'] / df_whitewine_m['pH']
df_whitewine_m['free_sulfur_dioxide_to_total_sulfur_dioxide_ratio'] = df_whitewine_m['free_sulfur_dioxide'] / df_whitewine_m['total_sulfur_dioxide']
df_whitewine_m['alcohol_to_acidity_ratio'] = df_whitewine_m['alcohol'] / df_whitewine_m['total_acidity']
df_whitewine_m['residual_sugar_to_citric_acid_ratio'] = df_whitewine_m['residual_sugar'] / df_whitewine_m['citric_acid']
df_whitewine_m['alcohol_to_density_ratio'] = df_whitewine_m['alcohol'] / df_whitewine_m['density']
df_whitewine_m['total_alkalinity'] = df_whitewine_m['pH'] + df_whitewine_m['alcohol']
df_whitewine_m['total_minerals'] = df_whitewine_m['chlorides'] + df_whitewine_m['sulphates'] + df_whitewine_m['residual_sugar']
    
# Cleaning inf or null values that may result from the operations above
df_whitewine_m = df_whitewine_m.replace([np.inf, -np.inf], 0)
df_whitewine_m = df_whitewine_m.dropna()

# %%
df_whitewine_m[['total_acidity',
       'acidity_to_pH_ratio',
       'free_sulfur_dioxide_to_total_sulfur_dioxide_ratio',
       'alcohol_to_acidity_ratio', 'residual_sugar_to_citric_acid_ratio',
       'alcohol_to_density_ratio', 'total_alkalinity', 'total_minerals']]
# Out:
#       total_acidity  acidity_to_pH_ratio  \
# 0              7.63             2.543333
# 1              6.94             2.103030
# 2              8.78             2.693252
# 3              7.75             2.429467
# 4              7.75             2.429467
# ...             ...                  ...
# 4893           6.70             2.048930
# 4894           7.28             2.311111
# 4895           6.93             2.317726
# 4896           6.09             1.823353
# 4897           6.59             2.021472
#
#       free_sulfur_dioxide_to_total_sulfur_dioxide_ratio  \
# 0                                              0.264706
# 1                                              0.106061
# 2                                              0.309278
# 3                                              0.252688
# 4                                              0.252688
# ...                                                 ...
# 4893                                           0.260870
# ...

# %%
df_redwine_m = df_redwine.copy()

# Creating new columns
df_redwine_m.columns = df_redwine_m.columns.str.replace(' ', '_')
df_redwine_m['total_acidity'] = df_redwine_m['fixed_acidity'] + df_redwine_m['volatile_acidity'] + df_redwine_m['citric_acid']
df_redwine_m['acidity_to_pH_ratio'] = df_redwine_m['total_acidity'] / df_redwine_m['pH']
df_redwine_m['free_sulfur_dioxide_to_total_sulfur_dioxide_ratio'] = df_redwine_m['free_sulfur_dioxide'] / df_redwine_m['total_sulfur_dioxide']
df_redwine_m['alcohol_to_acidity_ratio'] = df_redwine_m['alcohol'] / df_redwine_m['total_acidity']
df_redwine_m['residual_sugar_to_citric_acid_ratio'] = df_redwine_m['residual_sugar'] / df_redwine_m['citric_acid']
df_redwine_m['alcohol_to_density_ratio'] = df_redwine_m['alcohol'] / df_redwine_m['density']
df_redwine_m['total_alkalinity'] = df_redwine_m['pH'] + df_redwine_m['alcohol']
df_redwine_m['total_minerals'] = df_redwine_m['chlorides'] + df_redwine_m['sulphates'] + df_redwine_m['residual_sugar']
    
# Cleaning inf or null values that may result from the operations above
df_redwine_m = df_redwine_m.replace([np.inf, -np.inf], 0)
df_redwine_m = df_redwine_m.dropna()

# %%
df_redwine_m[['total_acidity',
       'acidity_to_pH_ratio',
       'free_sulfur_dioxide_to_total_sulfur_dioxide_ratio',
       'alcohol_to_acidity_ratio', 'residual_sugar_to_citric_acid_ratio',
       'alcohol_to_density_ratio', 'total_alkalinity', 'total_minerals']]
# Out:
#       total_acidity  acidity_to_pH_ratio  \
# 0             8.100             2.307692
# 1             8.680             2.712500
# 2             8.600             2.638037
# 3            12.040             3.810127
# 4             8.100             2.307692
# ...             ...                  ...
# 1594          6.880             1.994203
# 1595          6.550             1.860795
# 1596          6.940             2.029240
# 1597          6.665             1.866947
# 1598          6.780             2.000000
#
#       free_sulfur_dioxide_to_total_sulfur_dioxide_ratio  \
# 0                                              0.323529
# 1                                              0.373134
# 2                                              0.277778
# 3                                              0.283333
# 4                                              0.323529
# ...                                                 ...
# 1594                                           0.727273
# ...

# %% [markdown]
# These additional attributes are calculated based on the original physicochemical test variables and can provide further insights into the characteristics of the wine.

# %% [markdown]
# Binary Feature Engineering

# %%
# Creating a copy of the dataframe
copy_df = merge_df.copy()
copy_df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  wine_type
# 0      9.4          0
# 1      9.8          0
# 2      9.8          0

# %%
# Creating new columns
copy_df.columns = copy_df.columns.str.replace(' ', '_')
copy_df['total_acidity'] = copy_df['fixed_acidity'] + copy_df['volatile_acidity'] + copy_df['citric_acid']
copy_df['acidity_to_pH_ratio'] = copy_df['total_acidity'] / copy_df['pH']
copy_df['free_sulfur_dioxide_to_total_sulfur_dioxide_ratio'] = copy_df['free_sulfur_dioxide'] / copy_df['total_sulfur_dioxide']
copy_df['alcohol_to_acidity_ratio'] = copy_df['alcohol'] / copy_df['total_acidity']
copy_df['residual_sugar_to_citric_acid_ratio'] = copy_df['residual_sugar'] / copy_df['citric_acid']
copy_df['alcohol_to_density_ratio'] = copy_df['alcohol'] / copy_df['density']
copy_df['total_alkalinity'] = copy_df['pH'] + copy_df['alcohol']
copy_df['total_minerals'] = copy_df['chlorides'] + copy_df['sulphates'] + copy_df['residual_sugar']
    
# Cleaning the data or removing the null values that may result from the operations above
copy_df = copy_df.replace([np.inf, -np.inf], 0)
copy_df = copy_df.dropna()

# %%
copy_df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'wine_type', 'total_acidity',
#        'acidity_to_pH_ratio',
#        'free_sulfur_dioxide_to_total_sulfur_dioxide_ratio',
#        'alcohol_to_acidity_ratio', 'residual_sugar_to_citric_acid_ratio',
#        'alcohol_to_density_ratio', 'total_alkalinity', 'total_minerals'],
#       dtype='object')

# %% [markdown]
# <h1 id = 'feature_value_distribution' style="border-bottom: 1px solid #ccc;
#                         padding-bottom: 10px;
#                         margin-bottom: 10px;
#                         font-size: 38px;
#                         font-weight: bold;
#                         color: White;
#                         font-family: Poppins">Feature Value Distribution</h1>

# %% [markdown]
# MultiClassification Feature Value Distribution

# %%
for column in df_whitewine_m.select_dtypes(include='number'):
    plt.hist(df_whitewine_m[column], bins=10)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
plot_correlation(df_whitewine)

# %%
for column in df_redwine_m.select_dtypes(include='number'):
    plt.hist(df_redwine_m[column], bins=10)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
plot_correlation(df_redwine)

# %% [markdown]
# Binary Classification Feature Value Distribution

# %%
for column in merge_df.select_dtypes(include='number'):
    plt.hist(merge_df[column], bins=10)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
plot_correlation(merge_df)

# %%
visualize_labels(merge_df, 'fixed acidity', 'citric acid', 'wine_type')

# %% [markdown]
# <h1 id = 'standardizing' style="border-bottom: 1px solid #ccc;
#                         padding-bottom: 10px;
#                         margin-bottom: 10px;
#                         font-size: 38px;
#                         font-weight: bold;
#                         color: white;
#                         font-family: Poppins">Standardizing</h1>

# %% [markdown]
# MultiClassification Standardizing

# %% [markdown]
# * White Wine

# %%
# Split x and y
x_wm = df_whitewine_m.drop('quality', axis = 1)
y_wm = df_whitewine_m['quality']

x_train_wm, x_test_wm, y_train_wm, y_test_wm = train_test_split(x_wm, y_wm, test_size=0.20, random_state=20)


sc = StandardScaler()
x_train_wm_sc = sc.fit_transform(x_train_wm)
x_test_wm_sc = sc.fit_transform(x_test_wm)
dfwm_sc = pd.DataFrame(x_train_wm_sc, columns=x_wm.columns)

# %%
len(x_train_wm), len(x_test_wm), len(y_train_wm), len(y_test_wm)
# Out:
# (3918, 980, 3918, 980)

# %% [markdown]
# * Red Wine

# %%
# Split x and y
x_rm = df_redwine_m.drop('quality', axis = 1)
y_rm = df_redwine_m['quality']

x_train_rm, x_test_rm, y_train_rm, y_test_rm = train_test_split(x_rm, y_rm, test_size=0.20, random_state=20)
len(x_train_rm), len(x_test_rm), len(y_train_rm), len(y_test_rm)

sc = StandardScaler()
x_train_rm_sc = sc.fit_transform(x_train_rm)
x_test_rm_sc = sc.fit_transform(x_test_rm)
dfrm_sc = pd.DataFrame(x_train_rm_sc, columns=x_rm.columns)

# %% [markdown]
# Binary Classification Standardizing

# %%
# Split x and y
x = copy_df.drop('wine_type', axis = 1)
y = copy_df['wine_type']

x_train_b, x_test_b, y_train_b, y_test_b = train_test_split(x, y, test_size=0.20, random_state=20)
len(x_train_b), len(x_test_b), len(y_train_b), len(y_test_b)

sc = StandardScaler()
x_sc_b = sc.fit_transform(x_train_b)
df_sc_b = pd.DataFrame(x_sc_b, columns=x.columns)

# %% [markdown]
# <h1 id = 'modelling' style="border-bottom: 1px solid #ccc;
#                         padding-bottom: 10px;
#                         margin-bottom: 10px;
#                         font-size: 38px;
#                         font-weight: bold;
#                         color: white;
#                         font-family: Poppins">Modelling</h1>

# %% [markdown]
# Mutli-Class Classification Modelling

# %% [markdown]
# * White Wine

# %%
df_whitewine_m.shape
# Out:
# (4898, 20)

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

classifiers = [
    ('KNN', KNeighborsClassifier()),
    ('LR', LogisticRegression(max_iter=1000)),
    ('NB', GaussianNB()),
    ('GBC', GradientBoostingClassifier()),
    ('SVC', SVC()),
    ('RFC', RandomForestClassifier()),
    ('DT', DecisionTreeClassifier())
]

results = {'Model': [], 'Average Accuracy': []}

for name, model in classifiers:
    cvs = cross_val_score(model, x_train_wm_sc, y_train_wm, cv=10)
    avg_accuracy = round(cvs.mean(), 3)
    results['Model'].append(name)
    results['Average Accuracy'].append(avg_accuracy)

results_df_wm_cv = pd.DataFrame(results)

# %%
print(results_df_wm_cv)
# Out:
#   Model  Average Accuracy
# 0   KNN             0.564
# 1    LR             0.540
# 2    NB             0.414
# 3   GBC             0.599
# 4   SVC             0.568
# 5   RFC             0.665
# 6    DT             0.591

# %% [markdown]
# * Red Wine

# %%
df_redwine_m.shape
# Out:
# (1599, 20)

# %%
classifiers = [
    ('KNN', KNeighborsClassifier()),
    ('LR', LogisticRegression(max_iter=1000)),
    ('NB', GaussianNB()),
    ('GBC', GradientBoostingClassifier()),
    ('SVC', SVC()),
    ('RFC', RandomForestClassifier()),
    ('DT', DecisionTreeClassifier())
]

results = {'Model': [], 'Average Accuracy': []}

for name, model in classifiers:
    cvs = cross_val_score(model, x_train_rm_sc, y_train_rm, cv=10)
    avg_accuracy = round(cvs.mean(), 3)
    results['Model'].append(name)
    results['Average Accuracy'].append(avg_accuracy)

results_df_rm_cv = pd.DataFrame(results)

# %%
print(results_df_rm_cv)
# Out:
#   Model  Average Accuracy
# 0   KNN             0.582
# 1    LR             0.593
# 2    NB             0.499
# 3   GBC             0.666
# 4   SVC             0.631
# 5   RFC             0.692
# 6    DT             0.625

# %% [markdown]
# Binary Classification Modelling

# %%
models = []
models.append(('KNN', KNeighborsClassifier()))
models.append(('LR', LogisticRegression()))
models.append(('NB', GaussianNB()))
models.append(('GBC', GradientBoostingClassifier()))
models.append(('SVC', SVC()))
models.append(('RFC', RandomForestClassifier()))
models.append(('DT', DecisionTreeClassifier()))

results = []

for name, model in models:
    cvs = cross_val_score(model, x_sc_b, y_train_b, cv=10)
    avg_accuracy = round(cvs.mean(), 3)
    
    results.append({'Model': name, 'Average Accuracy': avg_accuracy})

results_df_b = pd.DataFrame(results)
print(results_df_b)
# Out:
#   Model  Average Accuracy
# 0   KNN             0.994
# 1    LR             0.994
# 2    NB             0.966
# 3   GBC             0.994
# 4   SVC             0.996
# 5   RFC             0.996
# 6    DT             0.984

# %%
# Summary
sum_df = pd.concat([results_df_wm_cv,
           results_df_rm_cv,
           results_df_b],
           ignore_index=True,
           axis = 1)
sum_df.drop(2, axis = 1, inplace = True)
sum_df.drop(4, axis = 1, inplace = True)
sum_df.columns = ['Classifer', 'MultiClass: WhiteWine_Accuracy', "MultiClass: RedWine_Accuracy", 'Binary_Accuracy']
sum_df
# Out:
#   Classifer  MultiClass: WhiteWine_Accuracy  MultiClass: RedWine_Accuracy  \
# 0       KNN                           0.564                         0.582
# 1        LR                           0.540                         0.593
# 2        NB                           0.414                         0.499
# 3       GBC                           0.599                         0.666
# 4       SVC                           0.568                         0.631
# 5       RFC                           0.665                         0.692
# 6        DT                           0.591                         0.625
#
#    Binary_Accuracy
# 0            0.994
# 1            0.994
# 2            0.966
# 3            0.994
# 4            0.996
# 5            0.996
# 6            0.984

# %% [markdown]
# This model aims to classify the type of wine based on its physicochemical properties.\
# Link of app in huggingface: [Hugging Face Link](https://huggingface.co/spaces/sedeba19/Binary_Classification_Wine)

# %% [markdown]
# <h1 id = 'neural_network' style="border-bottom: 1px solid #ccc;
#                         padding-bottom: 10px;
#                         margin-bottom: 10px;
#                         font-size: 38px;
#                         font-weight: bold;
#                         color: white;
#                         font-family: Poppins">Deep Neural Network</h1>

# %% [markdown]
# MultiClassification Neural Network

# %% [markdown]
# * White Wine Quality

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from tensorflow.keras.utils import to_categorical
num_classes= 10
y_train_wm_cat = to_categorical(y_train_wm, num_classes=num_classes)
y_test_wm_cat = to_categorical(y_test_wm, num_classes=num_classes)
y_train_rm_cat = to_categorical(y_train_rm, num_classes=num_classes)
y_test_rm_cat = to_categorical(y_test_rm, num_classes=num_classes)

# %%
nn_model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(x_train_wm_sc.shape[1],)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(num_classes, activation='softmax')
])

nn_model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), 
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

nn_history = nn_model.fit(x_train_wm_sc, 
                          y_train_wm_cat, 
                          epochs=10,
                          validation_data=(x_test_wm_sc, y_test_wm_cat))
# Out:
# Epoch 1/10
# 2023-08-18 22:52:47.085283: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-08-18 22:52:47.085485: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 123/123 [==============================] - 1s 2ms/step - loss: 1.7741 - accuracy: 0.3632 - val_loss: 1.3355 - val_accuracy: 0.4684
# Epoch 2/10
# 123/123 [==============================] - 0s 956us/step - loss: 1.3471 - accuracy: 0.4640 - val_loss: 1.2530 - val_accuracy: 0.4908
# Epoch 3/10
# ...

# %%
final_train_accuracy = nn_history.history['accuracy'][-1]
final_val_accuracy = nn_history.history['val_accuracy'][-1]
print(f"Training Accuracy: {final_train_accuracy:.4f}")
print(f"Validation Accuracy: {final_val_accuracy:.4f}")

plt.plot(nn_history.history['accuracy'], label='Training Accuracy')
plt.plot(nn_history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.legend()
plt.show()

plt.plot(nn_history.history['loss'], label='Training Loss')
plt.plot(nn_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.show()
# Out:
# Training Accuracy: 0.5255
# Validation Accuracy: 0.5469

# %% [markdown]
# Learning Rate Curve

# %%
def create_uncompiled_model(input_shape, num_classes):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Input(shape=(x_train_wm_sc.shape[1],)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    return model

def adjust_learning_rate(dataset, num_classes, epochs=100):
    x_train_wm_sc, y_train_wm_cat = dataset

    input_shape = x_train_wm_sc.shape[1]
    model = create_uncompiled_model(input_shape, num_classes)

    lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-6 * 10**(epoch / 20))

    optimizer = tf.keras.optimizers.Adam()

    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
                  optimizer=optimizer,
                  metrics=["accuracy"])

    callbacks = [lr_schedule]

    history = model.fit(x_train_wm_sc, y_train_wm_cat, epochs=epochs, callbacks=callbacks)

    return history

# Define your dataset and num_classes
dataset = (x_train_wm_sc, y_train_wm_cat)
num_classes = 10

# Run the training with dynamic LR
lr_history = adjust_learning_rate(dataset, num_classes)
# Out:
# Epoch 1/100
# 123/123 [==============================] - 0s 1ms/step - loss: 2.5411 - accuracy: 0.0886 - lr: 1.0000e-06
# Epoch 2/100
# 123/123 [==============================] - 0s 737us/step - loss: 2.5307 - accuracy: 0.0990 - lr: 1.1220e-06
# Epoch 3/100
# 123/123 [==============================] - 0s 754us/step - loss: 2.5410 - accuracy: 0.0934 - lr: 1.2589e-06
# Epoch 4/100
# 123/123 [==============================] - 0s 716us/step - loss: 2.5273 - accuracy: 0.0978 - lr: 1.4125e-06
# Epoch 5/100
# 123/123 [==============================] - 0s 729us/step - loss: 2.5311 - accuracy: 0.1018 - lr: 1.5849e-06
# Epoch 6/100
# 123/123 [==============================] - 0s 732us/step - loss: 2.5175 - accuracy: 0.0972 - lr: 1.7783e-06
# Epoch 7/100
# 123/123 [==============================] - 0s 713us/step - loss: 2.5021 - accuracy: 0.0995 - lr: 1.9953e-06
# Epoch 8/100
# 123/123 [==============================] - 0s 728us/step - loss: 2.4854 - accuracy: 0.1082 - lr: 2.2387e-06
# ...

# %%
# Plot Learning Curve
learning_rates = lr_history.history['lr']
loss = lr_history.history['loss']

plt.semilogx(learning_rates, loss)
plt.xlabel('Learning Rate')
plt.ylabel('Loss')
plt.title('Learning Rate vs. Loss')
plt.grid()
plt.show()

# %%
# Define learning rate
learning_rates = [1e-3]
epochs_ = 50

lr_values = []
loss_values = []

for lr in learning_rates:
    nn_model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(x_train_wm_sc.shape[1],)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])
    
    nn_model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), 
                    optimizer=tf.keras.optimizers.Adam(learning_rate = lr),
                    metrics=['accuracy'])
    lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-6 * 10**(epoch / 20))
    history_wm = nn_model.fit(x_train_wm_sc, 
                           y_train_wm_cat, 
                           epochs=epochs_, 
                           verbose=0,
                           validation_data=(x_test_wm_sc, y_test_wm_cat), 
                           callbacks=[lr_schedule])
    
    lr_values.append(lr)
    loss_values.append(history_wm.history['loss'][-1])
    loss, accuracy = nn_model.evaluate(x_test_wm_sc, y_test_wm_cat, verbose=0)
    final_train_accuracy_wm = history_wm.history['accuracy'][-1]
    final_val_accuracy_wm = history_wm.history['val_accuracy'][-1]
    print(f"Training Accuracy: {final_train_accuracy:.4f}")
    print(f"Validation Accuracy: {final_val_accuracy:.4f}")

def plot_training_history_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.show()

# Plot
plot_training_history_loss(history_wm)
# Out:
# Training Accuracy: 0.5255
# Validation Accuracy: 0.5469

# %%
def plot_training_history_accuracy(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='lower right')
    plt.show()

plot_training_history_accuracy(history_wm)

# %% [markdown]
# * Red Wine Quality

# %%
history_rm = nn_model.fit(x_train_rm_sc, 
                            y_train_rm_cat, 
                            epochs=epochs_, 
                            verbose=0,
                            validation_data=(x_test_rm_sc, y_test_rm_cat), 
                            callbacks=[lr_schedule])

final_train_accuracy_rm = history_rm .history['accuracy'][-1]
final_val_accuracy_rm = history_rm .history['val_accuracy'][-1]
print(f"Training Accuracy: {final_train_accuracy:.4f}")
print(f"Validation Accuracy: {final_val_accuracy:.4f}")
# Out:
# Training Accuracy: 0.5255
# Validation Accuracy: 0.5469

# %%
plot_training_history_loss(history_rm)

# %%
plot_training_history_accuracy(history_rm)

# %% [markdown]
# Binary Classification Neural Network\
# As for binary classification, the model has achieved nearly flawless accuracy, it is good to go.

# %%
# Save model to disk
import joblib
joblib.dump(nn_model, 'DNN_Model.pkl')
joblib.dump(SVC, 'SVC.pkl')
joblib.dump(SVC, 'RFC.pkl')
# Out:
# ['RFC.pkl']

# %% [markdown]
# <h1 id = 'conclusion' style="border-bottom: 1px solid #ccc;
#                         padding-bottom: 10px;
#                         margin-bottom: 10px;
#                         font-size: 38px;
#                         font-weight: bold;
#                         color: white;
#                         font-family: Poppins">Conclusion</h1>

# %%
sum_df.loc[len(sum_df)]= ['DNN', 0.5163, 0.5906, np.nan]
sum_df
# Out:
#   Classifer  MultiClass: WhiteWine_Accuracy  MultiClass: RedWine_Accuracy  \
# 0       KNN                          0.5640                        0.5820
# 1        LR                          0.5400                        0.5930
# 2        NB                          0.4140                        0.4990
# 3       GBC                          0.5990                        0.6660
# 4       SVC                          0.5680                        0.6310
# 5       RFC                          0.6650                        0.6920
# 6        DT                          0.5910                        0.6250
# 7       DNN                          0.5163                        0.5906
#
#    Binary_Accuracy
# 0            0.994
# 1            0.994
# 2            0.966
# 3            0.994
# 4            0.996
# 5            0.996
# 6            0.984
# 7              NaN

# %% [markdown]
# Broadly speaking, the Random Forest Classifier and Support Vector Classifier stand out for achieving an impressive binary accuracy of 99.6%. Additionally, the Gradient Boosting Classifier, K-Nearest Neighbors, and Logistic Regression exhibit commendable binary accuracy performances.
#
# It's apparent that the models fall short of being optimal, particularly when dealing with multiclass classification tasks. Nevertheless, these results should not constrain our potential. Possibilities for enhancement remain accessible through meticulous refinement, with special attention directed towards the refinement of the Deep Neural Network model.
#
# The value of data-driven methodologies in the context of wine assessment becomes apparent. By synergizing data exploration, feature engineering, and advanced modeling techniques, we can uncover latent patterns and trends within the data. This journey doesn't conclude here; the continuous fine-tuning of models and exploration of novel data sources have the potential to further enhance the precision and relevance of our predictions.
#
# The models are deployed on huggingface. You may refer below links for your reference.
# * [wine_type_predictor_app](https://huggingface.co/spaces/sedeba19/Binary_Classification_Wine)
# * [wine_quality_predictor_app](https://huggingface.co/spaces/sedeba19/wine_prediction_streamlit)
#
# The code can be found in the GitHub repository: [sedeba19](https://github.com/sedeba19)
#
# I trust you've gained valuable insights from this endeavor. Please do express your reflections and input in the comments section, and don't hesitate to give it a thumbs up if you discovered merit in this undertaking.
#
# Thank you for dedicating your time to read through this.
